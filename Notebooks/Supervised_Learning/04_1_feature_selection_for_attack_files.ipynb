# %%
##  "attacks" folder (with attack csv files) is required for the operation of the program.
##  "attacks" folder must be located in the same directory as the program.


##  the purpose of this code is to determine which features to use in the machine learning phase.
##  for this purpose, the importance weights of the attacks are calculated.
##  this calculation was made using sklearn-RandomForestRegressor.


import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestRegressor
import sklearn as sk
import time
seconds = time.time()

def folder(f_name): #this function creates a folder named "feature_pics" in the program directory.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")
        

# CSV files names:
csv_files=os.listdir("attacks")# It creates a list of file names in the "attacks" folder.

# Headers of column
main_labels=['Destination Port', 'Flow Duration', 'Total Fwd Packets', 'Total Backward Packets', 'Total Length of Fwd Packets', 'Total Length of Bwd Packets', 'Fwd Packet Length Max',
 'Fwd Packet Length Min', 'Fwd Packet Length Mean', 'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 'Bwd Packet Length Mean', 'Bwd Packet Length Std',
 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min',
 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
 'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s', 'Min Packet Length', 'Max Packet Length', 'Packet Length Mean', 'Packet Length Std', 'Packet Length Variance',
 'FIN Flag Count', 'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count', 'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Down/Up Ratio', 'Average Packet Size',
 'Avg Fwd Segment Size', 'Avg Bwd Segment Size', 'Fwd Header Length', 'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk', 'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk',
 'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', 'Subflow Fwd Bytes', 'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'act_data_pkt_fwd',
 'min_seg_size_forward', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min', 'Label']

ths = open("importance_list_for_attack_files.csv", "w")
folder("feature_pics/")
for j in csv_files:
    df=pd.read_csv("attacks/"+j,usecols=main_labels)
    df=df.fillna(0)
    attack_or_not=[]
    for i in df["Label"]:#it changes the normal label to "1" and the attack tag to "0" for use in the machine learning algorithm
        if i =="BENIGN":
            attack_or_not.append(1)
        else:
            attack_or_not.append(0)           
    df["Label"]=attack_or_not

    y = df["Label"].values
    df.drop("Label", axis =1, inplace = True)
    X = df.values
    
    X = np.float32(X)
    X[np.isnan(X)] = 0
    X[np.isinf(X)] = 0
   

    #computing the feature importances
    forest = sk.ensemble.RandomForestRegressor(n_estimators=250,random_state=0)
    forest.fit(X, y)
    importances = forest.feature_importances_
    std = np.std([tree.feature_importances_ for tree in forest.estimators_],
                 axis=0)
    indices = np.argsort(importances)[::-1]
    refclasscol=list(df.columns.values)
    impor_bars = pd.DataFrame({'Features':refclasscol[0:20],'importance':importances[0:20]})
    impor_bars = impor_bars.sort_values('importance',ascending=False).set_index('Features')
    plt.rcParams['figure.figsize'] = (10, 5)
    impor_bars.plot.bar();
    #printing the feature importances  
    count=0
    feature=j[0:-4]+"=["
    for i in impor_bars.index:
        feature=feature+"\""+str(i)+"\","
        count+=1
        if count==5:
            feature=feature[0:-1]+"]"
            break     
    print(j[0:-4],"importance list:")
    print(j[0:-4],"\n",impor_bars.head(20),"\n\n\n")
    print(feature)
    plt.title(j[0:-4]+" Attack - Feature Importance")
    plt.ylabel('Importance')
    plt.savefig("feature_pics/"+j[0:-4]+".pdf",bbox_inches='tight', papertype = 'a4', orientation = 'portrait', format = 'pdf')
    ths.write((  feature ) )
    plt.tight_layout()
    plt.show()
    print("-----------------------------------------------------------------------------------------------\n\n\n\n")

    
print("mission accomplished!")
print("Total operation time: = ",time.time()- seconds ,"seconds")
ths.close()
# Out:
# DDoS importance list:
# DDoS
#                               importance
# Features
# Fwd Packet Length Max          0.606766
# Total Length of Fwd Packets    0.179035
# Destination Port               0.003051
# Bwd Packet Length Min          0.000633
# Flow IAT Min                   0.000384
# Bwd Packet Length Mean         0.000112
# Total Backward Packets         0.000049
# Flow Bytes/s                   0.000030
# Fwd Packet Length Std          0.000025
# Flow IAT Mean                  0.000016
# Flow Duration                  0.000013
# Flow IAT Std                   0.000012
# Flow IAT Max                   0.000011
# Bwd Packet Length Max          0.000010
# Fwd Packet Length Mean         0.000009
# Total Length of Bwd Packets    0.000009
# Flow Packets/s                 0.000005
# Fwd Packet Length Min          0.000005
# Total Fwd Packets              0.000001
# Bwd Packet Length Std          0.000001
#
#
#
# DDoS=["Fwd Packet Length Max","Total Length of Fwd Packets","Destination Port","Bwd Packet Length Min","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS GoldenEye importance list:
# DoS GoldenEye
#                               importance
# Features
# Bwd Packet Length Std          0.580264
# Flow IAT Min                   0.154190
# Destination Port               0.046466
# Fwd Packet Length Min          0.027322
# Flow IAT Mean                  0.021870
# Flow IAT Std                   0.003459
# Total Backward Packets         0.001390
# Flow IAT Max                   0.000707
# Flow Duration                  0.000624
# Fwd Packet Length Mean         0.000197
# Flow Packets/s                 0.000193
# Total Length of Bwd Packets    0.000192
# Fwd Packet Length Max          0.000137
# Bwd Packet Length Mean         0.000122
# Total Fwd Packets              0.000057
# Flow Bytes/s                   0.000048
# Bwd Packet Length Max          0.000021
# Total Length of Fwd Packets    0.000021
# Fwd Packet Length Std          0.000013
# Bwd Packet Length Min          0.000006
#
#
#
# DoS GoldenEye=["Bwd Packet Length Std","Flow IAT Min","Destination Port","Fwd Packet Length Min","Flow IAT Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS Hulk importance list:
# DoS Hulk
#                                 importance
# Features
# Bwd Packet Length Std        5.852905e-01
# Destination Port             1.607457e-01
# Flow IAT Mean                5.062759e-02
# Flow IAT Std                 1.872471e-03
# Flow IAT Min                 3.942786e-04
# Total Backward Packets       2.868278e-04
# Flow IAT Max                 2.497225e-04
# Flow Duration                1.437248e-04
# Flow Bytes/s                 1.041138e-04
# Flow Packets/s               9.053821e-05
# Total Fwd Packets            5.605544e-05
# Total Length of Bwd Packets  3.095023e-05
# Bwd Packet Length Min        1.566679e-05
# Bwd Packet Length Mean       1.069150e-05
# Bwd Packet Length Max        6.444579e-06
# Fwd Packet Length Mean       5.326664e-06
# Fwd Packet Length Std        4.521073e-06
# Total Length of Fwd Packets  3.883247e-06
# Fwd Packet Length Max        2.528831e-06
# Fwd Packet Length Min        6.461580e-07
#
#
#
# DoS Hulk=["Bwd Packet Length Std","Destination Port","Flow IAT Mean","Flow IAT Std","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS slowloris importance list:
# DoS slowloris
#                               importance
# Features
# Flow IAT Mean                  0.489166
# Bwd Packet Length Mean         0.124586
# Destination Port               0.099749
# Total Length of Bwd Packets    0.004779
# Flow IAT Min                   0.001070
# Fwd Packet Length Max          0.001062
# Fwd Packet Length Std          0.000508
# Flow IAT Max                   0.000459
# Flow IAT Std                   0.000417
# Total Length of Fwd Packets    0.000403
# Bwd Packet Length Std          0.000384
# Flow Bytes/s                   0.000381
# Flow Duration                  0.000292
# Bwd Packet Length Max          0.000263
# Fwd Packet Length Mean         0.000222
# Total Fwd Packets              0.000161
# Flow Packets/s                 0.000144
# Total Backward Packets         0.000136
# Fwd Packet Length Min          0.000075
# Bwd Packet Length Min          0.000001
#
#
#
# DoS slowloris=["Flow IAT Mean","Bwd Packet Length Mean","Destination Port","Total Length of Bwd Packets","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS Slowhttptest importance list:
# DoS Slowhttptest
#                               importance
# Features
# Flow IAT Mean                  0.652665
# Fwd Packet Length Min          0.111561
# Bwd Packet Length Std          0.041924
# Bwd Packet Length Mean         0.034868
# Destination Port               0.030089
# Bwd Packet Length Max          0.002395
# Flow IAT Min                   0.002103
# Total Length of Bwd Packets    0.002041
# Total Fwd Packets              0.001724
# Fwd Packet Length Max          0.001294
# Fwd Packet Length Mean         0.000732
# Total Length of Fwd Packets    0.000594
# Flow Duration                  0.000532
# Bwd Packet Length Min          0.000415
# Fwd Packet Length Std          0.000398
# Flow IAT Max                   0.000366
# Flow Bytes/s                   0.000232
# Flow IAT Std                   0.000109
# Flow Packets/s                 0.000074
# Total Backward Packets         0.000044
#
#
#
# DoS Slowhttptest=["Flow IAT Mean","Fwd Packet Length Min","Bwd Packet Length Std","Bwd Packet Length Mean","Destination Port"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# FTP-Patator importance list:
# FTP-Patator
#                               importance
# Features
# Destination Port               0.990649
# Flow IAT Min                   0.000109
# Fwd Packet Length Max          0.000042
# Total Backward Packets         0.000035
# Total Fwd Packets              0.000027
# Flow IAT Max                   0.000023
# Total Length of Bwd Packets    0.000021
# Bwd Packet Length Mean         0.000015
# Flow Duration                  0.000014
# Total Length of Fwd Packets    0.000014
# Bwd Packet Length Max          0.000014
# Bwd Packet Length Std          0.000012
# Flow IAT Mean                  0.000009
# Flow Packets/s                 0.000009
# Fwd Packet Length Std          0.000000
# Fwd Packet Length Mean         0.000000
# Flow Bytes/s                   0.000000
# Flow IAT Std                   0.000000
# Fwd Packet Length Min          0.000000
# Bwd Packet Length Min          0.000000
#
#
#
# FTP-Patator=["Destination Port","Flow IAT Min","Fwd Packet Length Max","Total Backward Packets","Total Fwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Heartbleed importance list:
# Heartbleed
#                               importance
# Features
# Total Backward Packets            0.072
# Bwd Packet Length Std             0.056
# Bwd Packet Length Max             0.052
# Total Fwd Packets                 0.052
# Total Length of Bwd Packets       0.048
# Bwd Packet Length Mean            0.040
# Flow Duration                     0.024
# Total Length of Fwd Packets       0.016
# Flow IAT Min                      0.012
# Fwd Packet Length Max             0.008
# Fwd Packet Length Std             0.000
# Fwd Packet Length Mean            0.000
# Bwd Packet Length Min             0.000
# Fwd Packet Length Min             0.000
# Flow Bytes/s                      0.000
# Flow Packets/s                    0.000
# Flow IAT Mean                     0.000
# Flow IAT Std                      0.000
# Flow IAT Max                      0.000
# Destination Port                  0.000
#
#
#
# Heartbleed=["Total Backward Packets","Bwd Packet Length Std","Bwd Packet Length Max","Total Fwd Packets","Total Length of Bwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Infiltration importance list:
# Infiltration
#                               importance
# Features
# Fwd Packet Length Mean         0.206150
# Total Length of Fwd Packets    0.108900
# Destination Port               0.086038
# Flow IAT Max                   0.023131
# Flow Duration                  0.014890
# Flow IAT Std                   0.011049
# Flow IAT Min                   0.008652
# Flow Bytes/s                   0.005181
# Flow IAT Mean                  0.004589
# Fwd Packet Length Std          0.004275
# Flow Packets/s                 0.003442
# Bwd Packet Length Mean         0.002941
# Fwd Packet Length Max          0.002407
# Total Backward Packets         0.001384
# Bwd Packet Length Max          0.001353
# Bwd Packet Length Std          0.000988
# Total Length of Bwd Packets    0.000980
# Bwd Packet Length Min          0.000872
# Fwd Packet Length Min          0.000618
# Total Fwd Packets              0.000474
#
#
#
# Infiltration=["Fwd Packet Length Mean","Total Length of Fwd Packets","Destination Port","Flow IAT Max","Flow Duration"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# SSH-Patator importance list:
# SSH-Patator
#                               importance
# Features
# Destination Port               0.974466
# Flow IAT Mean                  0.000251
# Flow Bytes/s                   0.000065
# Flow Duration                  0.000064
# Flow IAT Max                   0.000057
# Flow Packets/s                 0.000051
# Flow IAT Min                   0.000030
# Flow IAT Std                   0.000030
# Total Length of Fwd Packets    0.000020
# Total Fwd Packets              0.000018
# Fwd Packet Length Mean         0.000016
# Fwd Packet Length Max          0.000016
# Total Length of Bwd Packets    0.000015
# Total Backward Packets         0.000013
# Fwd Packet Length Std          0.000009
# Bwd Packet Length Max          0.000008
# Fwd Packet Length Min          0.000006
# Bwd Packet Length Min          0.000006
# Bwd Packet Length Mean         0.000002
# Bwd Packet Length Std          0.000000
#
#
#
# SSH-Patator=["Destination Port","Flow IAT Mean","Flow Bytes/s","Flow Duration","Flow IAT Max"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# PortScan importance list:
# PortScan
#                                 importance
# Features
# Total Length of Fwd Packets  3.499486e-01
# Flow Bytes/s                 3.177359e-01
# Destination Port             2.608754e-03
# Flow Duration                7.189791e-04
# Bwd Packet Length Std        3.450105e-04
# Fwd Packet Length Max        1.142895e-04
# Flow IAT Mean                1.052718e-04
# Flow IAT Max                 7.486995e-05
# Flow IAT Min                 6.751814e-05
# Flow Packets/s               6.749674e-05
# Fwd Packet Length Std        4.992801e-05
# Total Fwd Packets            2.100557e-05
# Total Backward Packets       1.487940e-05
# Fwd Packet Length Mean       1.375101e-05
# Flow IAT Std                 1.163311e-05
# Bwd Packet Length Mean       7.943249e-06
# Total Length of Bwd Packets  7.420984e-06
# Bwd Packet Length Max        4.279562e-06
# Bwd Packet Length Min        2.391341e-06
# Fwd Packet Length Min        5.336032e-07
#
#
#
# PortScan=["Total Length of Fwd Packets","Flow Bytes/s","Destination Port","Flow Duration","Bwd Packet Length Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Web Attack importance list:
# Web Attack
#                               importance
# Features
# Destination Port               0.068993
# Flow IAT Max                   0.008376
# Total Length of Fwd Packets    0.006374
# Flow Bytes/s                   0.003375
# Flow Duration                  0.003107
# Bwd Packet Length Std          0.003072
# Fwd Packet Length Mean         0.002494
# Total Fwd Packets              0.001694
# Flow IAT Mean                  0.001583
# Flow Packets/s                 0.001437
# Bwd Packet Length Max          0.001371
# Flow IAT Min                   0.001352
# Fwd Packet Length Std          0.000766
# Fwd Packet Length Max          0.000507
# Bwd Packet Length Mean         0.000253
# Flow IAT Std                   0.000173
# Total Length of Bwd Packets    0.000122
# Total Backward Packets         0.000099
# Fwd Packet Length Min          0.000020
# Bwd Packet Length Min          0.000018
#
#
#
# Web Attack=["Destination Port","Flow IAT Max","Total Length of Fwd Packets","Flow Bytes/s","Flow Duration"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# mission accomplished!
# Total operation time: =  6428.691087245941 seconds

# %%
#Bo sung file attack bi thieu
csv_files = ['Bot.csv']

# %%
ths = open("importance_list_for_attack_files.csv", "a")
folder("feature_pics/")
for j in csv_files:
    df=pd.read_csv("attacks/"+j,usecols=main_labels)
    df=df.fillna(0)
    attack_or_not=[]
    for i in df["Label"]:#it changes the normal label to "1" and the attack tag to "0" for use in the machine learning algorithm
        if i =="BENIGN":
            attack_or_not.append(1)
        else:
            attack_or_not.append(0)           
    df["Label"]=attack_or_not

    y = df["Label"].values
    df.drop("Label", axis =1, inplace = True)
    X = df.values
    
    X = np.float32(X)
    X[np.isnan(X)] = 0
    X[np.isinf(X)] = 0
   

    #computing the feature importances
    forest = sk.ensemble.RandomForestRegressor(n_estimators=250,random_state=0)
    forest.fit(X, y)
    importances = forest.feature_importances_
    std = np.std([tree.feature_importances_ for tree in forest.estimators_],
                 axis=0)
    indices = np.argsort(importances)[::-1]
    refclasscol=list(df.columns.values)
    impor_bars = pd.DataFrame({'Features':refclasscol[0:20],'importance':importances[0:20]})
    impor_bars = impor_bars.sort_values('importance',ascending=False).set_index('Features')
    plt.rcParams['figure.figsize'] = (10, 5)
    impor_bars.plot.bar();
    #printing the feature importances  
    count=0
    feature=j[0:-4]+"=["
    for i in impor_bars.index:
        feature=feature+"\""+str(i)+"\","
        count+=1
        if count==5:
            feature=feature[0:-1]+"]"
            break     
    print(j[0:-4],"importance list:")
    print(j[0:-4],"\n",impor_bars.head(20),"\n\n\n")
    print(feature)
    plt.title(j[0:-4]+" Attack - Feature Importance")
    plt.ylabel('Importance')
    plt.savefig("feature_pics/"+j[0:-4]+".pdf",bbox_inches='tight', papertype = 'a4', orientation = 'portrait', format = 'pdf')
    ths.write((  feature ) )
    plt.tight_layout()
    plt.show()
    print("-----------------------------------------------------------------------------------------------\n\n\n\n")

    
print("mission accomplished!")
print("Total operation time: = ",time.time()- seconds ,"seconds")
ths.close()
# Out:
# Bot importance list:
# Bot
#                               importance
# Features
# Destination Port               0.574312
# Bwd Packet Length Mean         0.127532
# Flow IAT Std                   0.007625
# Flow IAT Min                   0.005513
# Flow IAT Mean                  0.000989
# Flow Duration                  0.000464
# Flow IAT Max                   0.000441
# Flow Packets/s                 0.000328
# Total Fwd Packets              0.000259
# Flow Bytes/s                   0.000238
# Total Backward Packets         0.000140
# Fwd Packet Length Max          0.000071
# Total Length of Bwd Packets    0.000046
# Bwd Packet Length Std          0.000043
# Total Length of Fwd Packets    0.000041
# Bwd Packet Length Max          0.000034
# Fwd Packet Length Mean         0.000014
# Bwd Packet Length Min          0.000010
# Fwd Packet Length Std          0.000005
# Fwd Packet Length Min          0.000003
#
#
#
# Bot=["Destination Port","Bwd Packet Length Mean","Flow IAT Std","Flow IAT Min","Flow IAT Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# mission accomplished!
# Total operation time: =  144.34264969825745 seconds
